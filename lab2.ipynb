# %% [markdown]
# ### Install Networkx

# %%
pip install networkx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Initial DFSGraph

# %%
from graph import DFSGraph
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout

g = DFSGraph()
for i in range(6):
    g.addVertex(i)
    g.addEdge(0,1,5)
    g.addEdge(0,4,2)
    g.addEdge(1,2,4)
    g.addEdge(1,3,6)
    g.addEdge(2,5,9)
    g.addEdge(3,5,3)
    g.addEdge(3,6,10)
    g.addEdge(6,8,8)
    g.addEdge(6,7,1)
for v in g:
    for w in v.getConnections():
        print("( %s , %s )" % (v.getId(), w.getId()))


# Visual graph
G1 = nx.Graph()
for v in g:
    for w in v.getConnections():
        G1.add_edge(v.getId(), w.getId())

pos = nx.spring_layout(G1)
nx.draw(G1, pos, node_size=1000, node_color='black', font_color='white', edge_color ='green', width = 2, with_labels= True)
# Out:
# ( 0 , 1 )
# ( 0 , 4 )
# ( 0 , 1 )
# ( 0 , 4 )
# ( 1 , 2 )
# ( 1 , 3 )
# ( 1 , 2 )
# ( 1 , 3 )
# ( 2 , 5 )
# ( 2 , 5 )
# ( 3 , 5 )
# ( 3 , 6 )
# ( 3 , 5 )
# ( 6 , 8 )
# ( 6 , 7 )

# %% [markdown]
# ### Traverse graph with DFS and print the route to the destination vertex

# %%
g.dfs()
print('Route to vertex 1')
g.traverse(g.getVertex(1))
print('Route to vertex 2')
g.traverse(g.getVertex(2))
print('Route to vertex 3')
g.traverse(g.getVertex(3))
print('Route to vertex 4')
g.traverse(g.getVertex(4))
print('Route to vertex 5')
g.traverse(g.getVertex(5))
print('Route to vertex 6')
g.traverse(g.getVertex(6))
print('Route to vertex 7')
g.traverse(g.getVertex(7))
print('Route to vertex 8')
g.traverse(g.getVertex(8))
# Out:
# Route to vertex 1
# 0->1
# Route to vertex 2
# 0->1->2
# Route to vertex 3
# 0->1->3
# Route to vertex 4
# 0->4
# Route to vertex 5
# 0->1->2->5
# Route to vertex 6
# 0->1->3->6
# Route to vertex 7
# 0->1->3->6->7
# Route to vertex 8
# 0->1->3->6->8

# %% [markdown]
# ### Initial BFSGraph

# %%
from graph import BFSGraph
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout

g = BFSGraph()
for i in range(6):
    g.addVertex(i)
    g.addEdge(0,1,5)
    g.addEdge(0,4,2)
    g.addEdge(1,2,4)
    g.addEdge(1,3,6)
    g.addEdge(2,5,9)
    g.addEdge(3,5,3)
    g.addEdge(3,6,10)
    g.addEdge(6,8,8)
    g.addEdge(6,7,1)
for v in g:
    for w in v.getConnections():
        print("( %s , %s )" % (v.getId(), w.getId()))

# Visual graph
G1 = nx.Graph()
for v in g:
    for w in v.getConnections():
        G1.add_edge(v.getId(), w.getId())

pos = nx.spring_layout(G1)
nx.draw(G1, pos, node_size=1000, node_color='black', font_color='white', edge_color ='green', width = 2, with_labels= True)
# Out:
# ( 0 , 1 )
# ( 0 , 4 )
# ( 0 , 1 )
# ( 0 , 4 )
# ( 1 , 2 )
# ( 1 , 3 )
# ( 1 , 2 )
# ( 1 , 3 )
# ( 2 , 5 )
# ( 2 , 5 )
# ( 3 , 5 )
# ( 3 , 6 )
# ( 3 , 5 )
# ( 6 , 8 )
# ( 6 , 7 )

# %% [markdown]
# ### Traverse graph with BFS and print the route to the destination vertex

# %%
g.bfs()
print('Route to vertex 1')
g.traverse(g.getVertex(1))
print('Route to vertex 2')
g.traverse(g.getVertex(2))
print('Route to vertex 3')
g.traverse(g.getVertex(3))
print('Route to vertex 4')
g.traverse(g.getVertex(4))
print('Route to vertex 5')
g.traverse(g.getVertex(5))
print('Route to vertex 6')
g.traverse(g.getVertex(6))
print('Route to vertex 7')
g.traverse(g.getVertex(7))
print('Route to vertex 8')
g.traverse(g.getVertex(8))
# Out:
# Route to vertex 1
# 0->1
# Route to vertex 2
# 0->1->2
# Route to vertex 3
# 0->1->3
# Route to vertex 4
# 0->4
# Route to vertex 5
# 0->1->2->5
# Route to vertex 6
# 0->1->3->6
# Route to vertex 7
# 0->1->3->6->7
# Route to vertex 8
# 0->1->3->6->8
